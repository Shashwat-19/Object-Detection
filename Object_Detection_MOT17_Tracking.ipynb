# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !git clone https://github.com/Shashwat-19/Object-Detection.git
# Out:
# fatal: destination path 'Object-Detection' already exists and is not an empty directory.

# %%
# !ls
# Out:
# LICENSE  main.py  README.md  requirements.txt  videos  yolov8n.pt

# %%
# %cd Object-Detection
# Out:
# [Errno 2] No such file or directory: 'Object-Detection'
# /content/Object-Detection

# %%
# !ls
# Out:
# LICENSE  main.py  README.md  requirements.txt  videos  yolov8n.pt

# %%
# !pip install -r requirements.txt
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 178.0/178.0 kB 8.1 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 52.8/52.8 kB 5.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.5/79.5 kB 7.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.1/60.1 kB 4.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.1/62.1 kB 4.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.4/3.4 MB 80.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 203.4/203.4 kB 21.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 72.3/72.3 kB 7.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 81.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.8/8.8 MB 134.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.6/16.6 MB 103.5 MB/s eta 0:00:00
# ...

# %%
# !pip install ultralytics supervision filterpy lap cython

# %%
import os
os.listdir("/content/drive/MyDrive/MOT17-02-FRCNN/img1")
# Out:
# ['000039.jpg',
#  '000001.jpg',
#  '000032.jpg',
#  '000040.jpg',
#  '000012.jpg',
#  '000041.jpg',
#  '000011.jpg',
#  '000007.jpg',
#  '000045.jpg',
#  '000047.jpg',
#  '000042.jpg',
#  '000010.jpg',
#  '000008.jpg',
#  '000017.jpg',
#  '000036.jpg',
#  '000015.jpg',
#  '000031.jpg',
#  '000048.jpg',
#  '000004.jpg',
#  '000022.jpg',
#  '000013.jpg',
#  '000009.jpg',
#  '000019.jpg',
#  '000016.jpg',
#  '000024.jpg',
#  '000020.jpg',
#  '000034.jpg',
#  '000018.jpg',
#  '000002.jpg',
#  '000033.jpg',
#  '000038.jpg',
#  '000030.jpg',
#  '000046.jpg',
#  '000029.jpg',
#  '000026.jpg',
#  '000037.jpg',
#  '000003.jpg',
#  '000027.jpg',
#  '000028.jpg',
#  '000035.jpg',
#  '000023.jpg',
#  '000049.jpg',
#  '000014.jpg',
#  '000025.jpg',
#  '000006.jpg',
#  '000044.jpg',
#  '000043.jpg',
#  '000005.jpg',
#  '000021.jpg',
#  '000143.jpg',
#  '000170.jpg',
#  '000178.jpg',
#  '000077.jpg',
#  '000132.jpg',
#  '000129.jpg',
#  '000162.jpg',
#  '000095.jpg',
#  '000119.jpg',
# ...

# %%
# !pip uninstall -y pillow
# !pip install pillow==10.2.0
# Out:
# Found existing installation: pillow 12.2.0
# Uninstalling pillow-12.2.0:
#   Successfully uninstalled pillow-12.2.0
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.5/4.5 MB 57.0 MB/s eta 0:00:00
# ...
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# gradio 5.50.0 requires pandas<3.0,>=1.0, but you have pandas 3.0.3 which is incompatible.
# ...

# %%
# !pip install --upgrade --force-reinstall ultralytics
# Out:
# ...
#   Using cached matplotlib-3.10.9-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (52 kB)
# ...
#   Using cached pillow-12.2.0-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (8.8 kB)
# ...
#   Using cached scipy-1.17.1-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (62 kB)
# ...
#   Using cached psutil-7.2.2-cp36-abi3-manylinux2010_x86_64.manylinux_2_12_x86_64.manylinux_2_28_x86_64.whl.metadata (22 kB)
# ...
#   Using cached polars-1.40.1-py3-none-any.whl.metadata (10 kB)
# ...
#   Using cached ultralytics_thop-2.0.19-py3-none-any.whl.metadata (14 kB)
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 118.7/118.7 kB 10.5 MB/s eta 0:00:00
# ...
#   Using cached packaging-26.2-py3-none-any.whl.metadata (3.5 kB)
# ...
#   Using cached polars_runtime_32-1.40.1-cp310-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (1.5 kB)
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.9/40.9 kB 3.9 MB/s eta 0:00:00
# ...

# %%
from ultralytics import YOLO

model = YOLO("yolov8m.pt")

results = model.track(
    source="/content/drive/MyDrive/MOT17-02-FRCNN/img1",
    tracker="bytetrack.yaml",
    save=True,
    show=False,
    device=0,
    conf=0.3
)
# Out:
# ...
#
# image 1/600 /content/drive/MyDrive/MOT17-02-FRCNN/img1/000001.jpg: 384x640 11 persons, 1 bench, 1 umbrella, 1 handbag, 65.3ms
# image 2/600 /content/drive/MyDrive/MOT17-02-FRCNN/img1/000002.jpg: 384x640 10 persons, 1 bench, 1 umbrella, 1 handbag, 25.1ms
# image 3/600 /content/drive/MyDrive/MOT17-02-FRCNN/img1/000003.jpg: 384x640 10 persons, 1 bench, 1 umbrella, 1 handbag, 25.1ms
# image 4/600 /content/drive/MyDrive/MOT17-02-FRCNN/img1/000004.jpg: 384x640 10 persons, 1 bench, 1 umbrella, 1 handbag, 25.2ms
# image 5/600 /content/drive/MyDrive/MOT17-02-FRCNN/img1/000005.jpg: 384x640 10 persons, 1 bench, 1 umbrella, 1 handbag, 25.2ms
# image 6/600 /content/drive/MyDrive/MOT17-02-FRCNN/img1/000006.jpg: 384x640 9 persons, 1 bench, 1 umbrella, 1 handbag, 25.2ms
# image 7/600 /content/drive/MyDrive/MOT17-02-FRCNN/img1/000007.jpg: 384x640 13 persons, 1 bench, 1 umbrella, 1 handbag, 25.3ms
# ...

# %%
# Navigate to the cloned repository directory
# %cd Object-Detection
# Out:
# [Errno 2] No such file or directory: 'Object-Detection'
# /content/Object-Detection

# %%
# !git config --global user.email "shashwat1956@gmail.com"
# !git config --global user.name "Shashwat-19"

# %%
# !git status
# Out:
# On branch main
# Your branch is up to date with 'origin/main'.
#
# Changes to be committed:
#   (use "git restore --staged <file>..." to unstage)
# 	new file:   yolov8m.pt

# %%
# Add all changes to the staging area
# !git add .

# %%
# !git status
# Out:
# On branch main
# Your branch is up to date with 'origin/main'.
#
# Changes to be committed:
#   (use "git restore --staged <file>..." to unstage)
# 	new file:   yolov8m.pt

# %%
# Commit the changes with a message
# !git commit -m "Update model tracking results from Colab"
# Out:
# [main 3096dbb] Update model tracking results from Colab
#  1 file changed, 0 insertions(+), 0 deletions(-)
#  create mode 100644 yolov8m.pt

# %%
# Push the changes to the remote repository
# You might be prompted for your GitHub username and password/personal access token
# !git push origin main
# Out:
# fatal: could not read Username for 'https://github.com': No such device or address

# %% [markdown]
# To push changes to GitHub from Colab, you need to use a Personal Access Token (PAT) instead of your password, as Git cannot prompt for credentials interactively. Follow these steps to generate and use a PAT:
#
# 1.  **Generate a Personal Access Token on GitHub**:
#     *   Go to your GitHub profile settings.
#     *   Navigate to `Developer settings` > `Personal access tokens` > `Tokens (classic)`.
#     *   Click `Generate new token`.
#     *   Give your token a descriptive name (e.g., 'Colab Access').
#     *   Select the `repo` scope to give it full control over private repositories.
#     *   Click `Generate token` and **copy the token immediately** (you won't be able to see it again).
#
# 2.  **Use the PAT in the `git push` command**: Replace `YOUR_PERSONAL_ACCESS_TOKEN` in the command below with the token you just generated.

# %%
# Push changes using a Personal Access Token (PAT)
# Replace 'YOUR_PERSONAL_ACCESS_TOKEN' with your actual token.
# Make sure your email and username are correctly configured as well.
# !git push https://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@github.com/Shashwat-19/Object-Detection.git main
# Out:
# Enumerating objects: 4, done.
# Counting objects: 100% (4/4), done.
# Delta compression using up to 2 threads
# Compressing objects: 100% (3/3), done.
# Writing objects: 100% (3/3), 45.98 MiB | 9.71 MiB/s, done.
# Total 3 (delta 1), reused 0 (delta 0), pack-reused 0
# remote: Resolving deltas: 100% (1/1), completed with 1 local object.
# To https://github.com/Shashwat-19/Object-Detection.git
#    d9c0ca0..3096dbb  main -> main

# %%
# Ensure we are in the correct repository directory
# %cd /content/Object-Detection
# Out:
# /content/Object-Detection

# %%
# List the contents of the current directory to see if 'runs' folder is present
# !ls -F
# Out:
# LICENSE  README.md	   runs/    yolov8m.pt
# main.py  requirements.txt  videos/  yolov8n.pt

# %%
# Check if 'runs' is listed in .gitignore
# !cat .gitignore
# Out:
# # Byte-compiled / optimized / DLL files
# __pycache__/
# *.py[codz]
# *$py.class
#
# # C extensions
# *.so
#
# # Distribution / packaging
# .Python
# build/
# develop-eggs/
# dist/
# downloads/
# eggs/
# .eggs/
# lib/
# lib64/
# parts/
# sdist/
# var/
# wheels/
# share/python-wheels/
# *.egg-info/
# .installed.cfg
# *.egg
# MANIFEST
#
# # PyInstaller
# #   Usually these files are written by a python script from a template
# #   before PyInstaller builds the exe, so as to inject date/other infos into it.
# *.manifest
# *.spec
#
# # Installer logs
# pip-log.txt
# pip-delete-this-directory.txt
#
# # Unit test / coverage reports
# htmlcov/
# .tox/
# .nox/
# .coverage
# .coverage.*
# .cache
# nosetests.xml
# coverage.xml
# *.cover
# *.py.cover
# .hypothesis/
# .pytest_cache/
# cover/
#
# # Translations
# *.mo
# *.pot
#
# # Django stuff:
# *.log
# local_settings.py
# db.sqlite3
# db.sqlite3-journal
#
# # Flask stuff:
# instance/
# .webassets-cache
#
# # Scrapy stuff:
# .scrapy
#
# ...

# %%
# Ensure we are in the correct repository directory
# %cd /content/Object-Detection
# Out:
# /content/Object-Detection

# %%
# Force add the 'runs' directory and its contents
# This bypasses the .gitignore rule for this specific commit
# !git add -f runs/

# %%
# !git status
# Out:
# On branch main
# Your branch is ahead of 'origin/main' by 1 commit.
#   (use "git push" to publish your local commits)
#
# Changes to be committed:
#   (use "git restore --staged <file>..." to unstage)
# 	new file:   runs/detect/track/000001.jpg
# 	new file:   runs/detect/track/000002.jpg
# 	new file:   runs/detect/track/000003.jpg
# 	new file:   runs/detect/track/000004.jpg
# 	new file:   runs/detect/track/000005.jpg
# 	new file:   runs/detect/track/000006.jpg
# 	new file:   runs/detect/track/000007.jpg
# 	new file:   runs/detect/track/000008.jpg
# 	new file:   runs/detect/track/000009.jpg
# 	new file:   runs/detect/track/000010.jpg
# 	new file:   runs/detect/track/000011.jpg
# 	new file:   runs/detect/track/000012.jpg
# 	new file:   runs/detect/track/000013.jpg
# 	new file:   runs/detect/track/000014.jpg
# 	new file:   runs/detect/track/000015.jpg
# 	new file:   runs/detect/track/000016.jpg
# 	new file:   runs/detect/track/000017.jpg
# 	new file:   runs/detect/track/000018.jpg
# ...

# %%
# Commit the changes with a message
# !git commit -m "Add runs folder with tracking results"
# Out:
# [main cc299a6] Add runs folder with tracking results
#  600 files changed, 0 insertions(+), 0 deletions(-)
#  create mode 100644 runs/detect/track/000001.jpg
#  create mode 100644 runs/detect/track/000002.jpg
#  create mode 100644 runs/detect/track/000003.jpg
#  create mode 100644 runs/detect/track/000004.jpg
#  create mode 100644 runs/detect/track/000005.jpg
#  create mode 100644 runs/detect/track/000006.jpg
#  create mode 100644 runs/detect/track/000007.jpg
#  create mode 100644 runs/detect/track/000008.jpg
#  create mode 100644 runs/detect/track/000009.jpg
#  create mode 100644 runs/detect/track/000010.jpg
#  create mode 100644 runs/detect/track/000011.jpg
#  create mode 100644 runs/detect/track/000012.jpg
#  create mode 100644 runs/detect/track/000013.jpg
#  create mode 100644 runs/detect/track/000014.jpg
#  create mode 100644 runs/detect/track/000015.jpg
#  create mode 100644 runs/detect/track/000016.jpg
#  create mode 100644 runs/detect/track/000017.jpg
# ...

# %%
# Push the changes to the remote repository using your PAT
# Replace YOUR_PERSONAL_ACCESS_TOKEN with your actual token
# !git push https://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@github.com/Shashwat-19/Object-Detection.git main
# Out:
# Enumerating objects: 606, done.
# Counting objects: 100% (606/606), done.
# Delta compression using up to 2 threads
# Compressing objects: 100% (603/603), done.
# Writing objects: 100% (605/605), 229.61 MiB | 11.94 MiB/s, done.
# Total 605 (delta 1), reused 0 (delta 0), pack-reused 0
# remote: Resolving deltas: 100% (1/1), completed with 1 local object.
# To https://github.com/Shashwat-19/Object-Detection.git
#    3096dbb..cc299a6  main -> main

# %%
# Change to the root content directory to look for the notebook
# %cd /content/

# List .ipynb files in the common Colab Notebooks directory in Google Drive
# This assumes your notebook is saved in Google Drive
print("Searching for .ipynb files in Google Drive...")
# !find /content/drive/MyDrive/ -name "*.ipynb"
# Out:
# /content
# Searching for .ipynb files in Google Drive...
# /content/drive/MyDrive/Colab Notebooks/Object_Detection_MOT17_Tracking.ipynb
# /content/drive/MyDrive/Colab Notebooks/BangaloreTraffic.ipynb
# /content/drive/MyDrive/Colab Notebooks/DeepLearning_CNN_CIFAR10_Classifier.ipynb
# /content/drive/MyDrive/Colab Notebooks/Untitled0.ipynb
# /content/drive/MyDrive/Colab Notebooks/RGB Color Channel Speration.ipynb
# /content/drive/MyDrive/Colab Notebooks/Untitled1.ipynb
# /content/drive/MyDrive/Colab Notebooks/Untitled2.ipynb
# /content/drive/MyDrive/Colab Notebooks/Untitled3.ipynb
# /content/drive/MyDrive/Colab Notebooks/Untitled4.ipynb
# /content/drive/MyDrive/Colab Notebooks/mobilenetv2-vegseeds-confidence-filtering (1).ipynb
# /content/drive/MyDrive/Colab Notebooks/mobilenetv2-vegseeds-confidence-filtering.ipynb
# /content/drive/MyDrive/Colab Notebooks/Copy of Apple Variety Classifier (10 Market Varieties) (2).ipynb
# ...

# %% [markdown]
# From the output above, identify the *full path* to `Object_Detection_MOT17_Tracking.ipynb` (or whatever its actual name is). It will likely be something like `/content/drive/MyDrive/Colab Notebooks/Object_Detection_MOT17_Tracking.ipynb`.
#
# Then, in the next cell, **replace `YOUR_NOTEBOOK_FULL_PATH`** with the path you found and execute it to move the notebook into your repository. If the notebook is not in Drive, you might need to manually save it into the `/content/Object-Detection/` folder using `File > Save a copy in GitHub` (if linked) or by downloading and re-uploading.

# %%
# MOVE the notebook from its actual location to your git repository
# IMPORTANT: Replace 'YOUR_NOTEBOOK_FULL_PATH' with the actual path found in the previous step
NOTEBOOK_SOURCE_PATH = "/content/drive/MyDrive/Colab Notebooks/Object_Detection_MOT17_Tracking.ipynb" # Example path, UPDATE THIS!
DESTINATION_DIR = "/content/Object-Detection/"

# Ensure destination directory exists (it should from cloning)
# !mkdir -p "{DESTINATION_DIR}"

# Move the notebook
# !mv "{NOTEBOOK_SOURCE_PATH}" "{DESTINATION_DIR}"
print(f"Moved {NOTEBOOK_SOURCE_PATH} to {DESTINATION_DIR}")

# Change into the repository directory
# %cd "{DESTINATION_DIR}"

# %%
# Verify the notebook is now in the directory
# !ls -F

# %%
# Add the notebook file to the staging area
# !git add "Object_Detection_MOT17_Tracking.ipynb"

# %%
# Commit the notebook file
# !git commit -m "Add Colab notebook file"

# %%
# Push the committed notebook to your GitHub repository using your PAT
# !git push https://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@github.com/Shashwat-19/Object-Detection.git main

# %%
# Add the notebook file to the staging area
# !git add "Object_Detection_MOT17_Tracking.ipynb"

# %%
# Commit the notebook file
# !git commit -m "Add Colab notebook file"

# %%
# Push the committed notebook to your GitHub repository using your PAT
# !git push https://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@github.com/Shashwat-19/Object-Detection.git main
